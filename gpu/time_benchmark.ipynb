# %%
import numpy as np
import matplotlib.pyplot as plt

grid_size =    [128, 256, 512, 1024, 2048, 4096, 8184, 16368, 32736, 65536]
elapsed_time = [12,   13,  18,   38,  118,  436, 1709,  6862, 30708, 110447]
grid_size = [x**2 for x in grid_size]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="GPU no reproducability")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240, 16368, 32736]
grid_size = [x**2 for x in grid_size]
elapsed_time = [6, 13, 57, 234, 921, 3693, 14688, 22987, 58786, 235139]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="GPU binary 1 t per byte")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240]
grid_size = [x**2 for x in grid_size]
elapsed_time = [6, 20, 74, 258, 1027, 4118, 16523, 25855]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="GPU binary 1 t per bit")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240]
grid_size = [x**2 for x in grid_size]
elapsed_time = [7, 20, 73, 277, 1100, 4420, 17686, 27475]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="GPU 2 arrays")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240]
grid_size = [x**2 for x in grid_size]
elapsed_time = [6, 21, 75, 269, 1069, 4296, 17193, 27050]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="GPU char (-10 Instr)")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240]
grid_size = [x**2 for x in grid_size]
elapsed_time = [7, 25, 91, 331, 1314, 5261, 21030, 32224]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="GPU 1x threads")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240]
grid_size = [x**2 for x in grid_size]
elapsed_time = [15, 30, 99, 376, 1465, 5834, 23372, 36526]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="GPU 2x threads")

grid_size = [128, 256, 512, 1024]
grid_size = [x**2 for x in grid_size]
elapsed_time = [6266, 11871, 31788, 105943]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.xlabel('Grid size')
plt.ylabel('Time ms')
plt.plot(grid_size, speedup, marker='o', label="CPU")
plt.legend()
plt.xscale('log', base=2) 
plt.yscale('log', base=10) 

# plt.plot(grid_size, speedup_two_threads, marker='o', label="Experiment speedup (2 threads per core)")
plt.savefig('ising_benchmark.png')
#plt.axline((grid_size[0], speedup[0]), slope=1, linestyle='dotted', color='black', label='Ideal speedup')

# %%
import numpy as np
import matplotlib.pyplot as plt

grid_size =    [128, 256, 512, 1024, 2048, 4096, 8184, 16368, 32736, 65536]
elapsed_time = [12,   13,  18,   38,  118,  436, 1709,  6862, 30708, 110447]
grid_size = [x**2 for x in grid_size]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="no reproducability")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240, 16368, 32736]
grid_size = [x**2 for x in grid_size]
elapsed_time = [6, 13, 57, 234, 921, 3693, 14688, 22987, 58786, 235139]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="binary 1 thread per byte")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240]
grid_size = [x**2 for x in grid_size]
elapsed_time = [6, 20, 74, 258, 1027, 4118, 16523, 25855]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="binary 1 thread per bit")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240]
grid_size = [x**2 for x in grid_size]
elapsed_time = [7, 20, 73, 277, 1100, 4420, 17686, 27475]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="2 arrays")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240]
grid_size = [x**2 for x in grid_size]
elapsed_time = [6, 21, 75, 269, 1069, 4296, 17193, 27050]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="char (-10 Instr)")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240]
grid_size = [x**2 for x in grid_size]
elapsed_time = [7, 25, 91, 331, 1314, 5261, 21030, 32224]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="1x threads")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240]
grid_size = [x**2 for x in grid_size]
elapsed_time = [15, 30, 99, 376, 1465, 5834, 23372, 36526]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="2x threads")

"""
grid_size = [128, 256, 512, 1024]
grid_size = [x**2 for x in grid_size]
elapsed_time = [6266, 11871, 31788, 105943]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="CPU")
"""
plt.xlabel('Grid size')
plt.ylabel('Time ms')
plt.legend()
plt.xscale('log', base=2) 
plt.yscale('log', base=10) 

# plt.plot(grid_size, speedup_two_threads, marker='o', label="Experiment speedup (2 threads per core)")
plt.savefig('ising_benchmark_only_GPU.png')
#plt.axline((grid_size[0], speedup[0]), slope=1, linestyle='dotted', color='black', label='Ideal speedup')

# %%
import numpy as np
import matplotlib.pyplot as plt

grid_size =    [128, 256, 512, 1024, 2048, 4096, 8184, 16368, 32736, 65536]
elapsed_time = [12,   13,  18,   38,  118,  436, 1709,  6862, 30708, 110447]
grid_size = [x**2 for x in grid_size]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="GPU no reproducability")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240, 16368, 32736]
grid_size = [x**2 for x in grid_size]
elapsed_time = [6, 13, 57, 234, 921, 3693, 14688, 22987, 58786, 235139]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="GPU binary 1 t per byte")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240]
grid_size = [x**2 for x in grid_size]
elapsed_time = [6, 20, 74, 258, 1027, 4118, 16523, 25855]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="GPU binary 1 t per bit")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240]
grid_size = [x**2 for x in grid_size]
elapsed_time = [7, 20, 73, 277, 1100, 4420, 17686, 27475]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="GPU 2 arrays")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240]
grid_size = [x**2 for x in grid_size]
elapsed_time = [6, 21, 75, 269, 1069, 4296, 17193, 27050]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="GPU char (-10 Instr)")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240]
grid_size = [x**2 for x in grid_size]
elapsed_time = [7, 25, 91, 331, 1314, 5261, 21030, 32224]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="GPU 1x threads")

grid_size = [128, 256, 512, 1024, 2048, 4096, 8184, 10240]
grid_size = [x**2 for x in grid_size]
elapsed_time = [15, 30, 99, 376, 1465, 5834, 23372, 36526]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.plot(grid_size, speedup, marker='o', label="GPU 2x threads")

grid_size = [128, 256, 512, 1024]
grid_size = [x**2 for x in grid_size]
elapsed_time = [6266, 11871, 31788, 105943]
time_pr_task = [elapsed_time[i] for i in range(len(grid_size))]

sequential_time = time_pr_task[0]
speedup = elapsed_time
plt.xlabel('Grid size')
plt.ylabel('Time ms')
plt.plot(grid_size, speedup, marker='o', label="CPU")
plt.legend()
plt.xscale('log', base=2) 
#plt.yscale('log', base=10) 

# plt.plot(grid_size, speedup_two_threads, marker='o', label="Experiment speedup (2 threads per core)")
plt.savefig('ising_benchmark_no_log_y.png')
#plt.axline((grid_size[0], speedup[0]), slope=1, linestyle='dotted', color='black', label='Ideal speedup')
